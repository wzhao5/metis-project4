# %%
import sys
sys.path.insert(1, '../src')
from util import *
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pandarallel import pandarallel
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.decomposition import NMF
import nltk
import warnings
from sklearn.decomposition import TruncatedSVD
from collections import defaultdict

# %%
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option("display.max_rows", 999)
pd.set_option("display.max_columns", None)
pd.set_option("precision", 3)
# %pylab inline
# %config InlineBackend.figure_formats = ['retina']
pandarallel.initialize()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# ## **1. Read clcean data**

# %%
fn = '../data/data_preprocessed.pickle'
data = read_from_pickle(fn)
df = data['df_original']
data.keys()
# Out:
# Read data from "../data/data_preprocessed.pickle"
# dict_keys(['df_words_tkn', 'dict_ngrams', 'df_original'])

# %% [markdown]
# ## **2. Here are some of my papers**

# %%
# my paper! proud of these!!!
df[(df['first_author']=='Wei Zhao') & (df['last_author']=='Songbai Ji')]
# Out:
#                                                    title  \
# 4238   Displacement Strain Discrimination Head Injury...
# 4503   Incorporation vasculature head injury model lo...
# 10701  Mesh Convergence Behavior Effect Element Integ...
# 13049  White Matter Anisotropy Impact Simulation Resp...
# 13851  Material properties brain injury relevant cond...
# 16405  Performance Evaluation Pre Brain Response Atla...
# 17132  Injury prediction vulnerability assessment str...
# 19544  White Matter Injury Susceptibility Fiber Strai...
# 19908  Brain strain uncertainty due variation simplif...
# 22342  Real time whole brain pressure responses trans...
# 26818  Brain pressure responses translational head di...
#
#                                                  journal  \
# 4238                    Annals of biomedical engineering
# 4503                             Journal of biomechanics
# 10701                   Annals of biomedical engineering
# 13049                             Journal of neurotrauma
# 13851  Journal of the mechanical behavior of biomedic...
# 16405                   Annals of biomedical engineering
# 17132        Biomechanics and modeling in mechanobiology
# 19544                             Journal of neurotrauma
# 19908        Biomechanics and modeling in mechanobiology
# 22342                                    Interface focus
# 26818        Biomechanics and modeling in mechanobiology
#
#                                                 keywords  \
# 4238   Anisotropy", "Concussion", "Head impact", "Mod...
# 4503   Finite element model", "Neuroimaging", "Trauma...
# 10701  Element integration", "Finite element model", ...
# 13049  Worcester Head Injury Model", "concussion", "t...
# 13851  Concussion", "Head injury model", "Hyperelasti...
# 16405  Concussion", "Contact sports", "Finite element...
# 17132  Concussion", "Deep white matter", "Fiber strai...
# 19544  Dartmouth Head Injury Model", "fiber strain", ...
# 19908  Brain strains", "Head angular motion", "Head i...
# 22342  Dartmouth head injury model", "Head Injury Cri...
# 26818
#
#                                                 abstract first_author  \
# 4238   Successful validation head injury model critic...     Wei Zhao
# 4503   Cerebral vasculature several orders magnitude ...     Wei Zhao
# 10701  Numerous head injury models vary mesh density ...     Wei Zhao
# 13049  Advanced new opportunities head injury models ...     Wei Zhao
# 13851  Material properties brain vast variations cons...     Wei Zhao
# 16405  pre brain response atlas pcBRA potential inves...     Wei Zhao
# 17132  Reliable prediction diagnosis concussion impor...     Wei Zhao
# 19544  Microscale brain injury studies axonal elongat...     Wei Zhao
# 19908  Head angular velocity acceleration predictive ...     Wei Zhao
# 22342  Theoretical debate role linear acceleration li...     Wei Zhao
# 26818  Brain pressure responses translational head im...     Wei Zhao
#
#       last_author  year                                 title_and_abstract  \
# 4238   Songbai Ji  2020  Displacement Strain Discrimination Head Injury...
# 4503   Songbai Ji  2020  Incorporation vasculature head injury model lo...
# 10701  Songbai Ji  2018  Mesh Convergence Behavior Effect Element Integ...
# 13049  Songbai Ji  2018  White Matter Anisotropy Impact Simulation Resp...
# 13851  Songbai Ji  2018  Material properties brain injury relevant cond...
# 16405  Songbai Ji  2017  Performance Evaluation Pre Brain Response Atla...
# 17132  Songbai Ji  2017  Injury prediction vulnerability assessment str...
# 19544  Songbai Ji  2016  White Matter Injury Susceptibility Fiber Strai...
# 19908  Songbai Ji  2016  Brain strain uncertainty due variation simplif...
# 22342  Songbai Ji  2016  Real time whole brain pressure responses trans...
# 26818  Songbai Ji  2014  Brain pressure responses translational head di...
#
#                                 title_and_abstract_lemma
# 4238   displacement strain discrimination head injury...
# 4503   incorporation vasculature head injury model lo...
# 10701  mesh convergence behavior effect element integ...
# 13049  white matter anisotropy impact simulation resp...
# 13851  material property brain injury relevant condit...
# 16405  performance evaluation pre brain response atla...
# 17132  injury prediction vulnerability assessment str...
# 19544  white matter injury susceptibility fiber strai...
# 19908  brain strain uncertainty due variation simplif...
# 22342  real time whole brain pressure response transl...
# 26818  brain pressure response translational head dim...

# %% [markdown]
# ## **3. Yearly counts of publications**

# %%
year = range(1991, 2022)
d = defaultdict(list)
c = defaultdict(list)

for y in year:
    c[y] = sum([df['year'] == y])

c = pd.Series(c, index=c.keys())
plt.subplots(figsize=(15, 6))
# ax = plt.bar(c.index, c, )

ax = sns.barplot(x=c.index, y=c,
                 color=(0.2, 0.4, 0.6),
                 edgecolor=(0,0,0),
                 linewidth=1.5)
ax.set_xticklabels(c.index,
                   rotation=45,
                   ha='center',
                   fontsize=15,
                  )
ax.set_yticklabels(ax.get_yticks(),
                   fontsize=15,
                  )
ax.set_xlabel('Year', fontsize=18,)
ax.set_ylabel('Counts of Publications', fontsize=18,)
[t_ax.set_width(1) for t_ax in ax.patches];
ax.set_xlim([-0.4,30.62])
ax.set_ylim([0, 5000]);
fn = '../figures/counts_of_publications.svg'
plt.savefig(fn, dpi=300, bbox_inches='tight', facecolor="white")

# %% [markdown]
# ## **4. Top 10 most popular journals identified based on cumulative counts of publications**

# %%
c = df['journal'].value_counts().head(10)
plt.subplots(figsize=(15, 6))
# ax = plt.bar(c.index, c, )

ax = sns.barplot(x=c.index, y=c,
                 color=(0.2, 0.4, 0.6),
                 edgecolor=(0,0,0),
                 linewidth=1.5)
ax.set_xticklabels(c.index,
                   rotation=45,
                   ha='center',
                   fontsize=15,
                  )
ax.set_yticklabels(ax.get_yticks(),
                   fontsize=15,
                  )
ax.set_ylabel('Counts of Publications', fontsize=18,)
[t_ax.set_width(1) for t_ax in ax.patches];
fn = '../figures/top_10_most_pop_journals_over_30_years.svg'
plt.savefig(fn, dpi=300, bbox_inches='tight', facecolor="white")

# %% [markdown]
# ## 5. Yearly most popular journal based on the counts of publications in that year

# %%
df_coutns_num = pd.DataFrame()
df_coutns_title = pd.DataFrame()

df_coutns_num = (df[['year', 'journal']]
     .groupby(['year'], as_index=False)
     .apply(lambda x: x['journal'].value_counts().iloc[0]))
df_coutns_title = (df[['year', 'journal']]
     .groupby(['year'], as_index=False)
     .apply(lambda x: x['journal'].value_counts().index[0]))
df_counts = df_coutns_num.merge(df_coutns_title,how='left', on='year')
df_counts.columns = ['year', 'Counts of Publications', 'Most Pop.Journal']
df_counts
# Out:
#     year  Counts of Publications             Most Pop.Journal
# 0   1991                      15                 Brain injury
# 1   1992                      29                 Brain injury
# 2   1993                      32                 Brain injury
# 3   1994                      37                 Brain injury
# 4   1995                      42                 Brain injury
# 5   1996                      47                 Brain injury
# 6   1997                      45                 Brain injury
# 7   1998                      56                 Brain injury
# 8   1999                      42       Journal of neurotrauma
# 9   2000                      66                 Brain injury
# 10  2001                      61                 Brain injury
# 11  2002                      52  Experimental brain research
# 12  2003                      67                 Brain injury
# 13  2004                      57       Journal of neurotrauma
# 14  2005                     102  Experimental brain research
# 15  2006                      93                 Brain injury
# 16  2007                      99       Journal of neurotrauma
# 17  2008                      81                 Brain injury
# 18  2009                     142       Journal of neurotrauma
# 19  2010                     115       Journal of neurotrauma
# 20  2011                     168       Journal of neurotrauma
# 21  2012                     141       Journal of neurotrauma
# 22  2013                     155       Journal of neurotrauma
# 23  2014                     180       Journal of neurotrauma
# 24  2015                     192       Journal of neurotrauma
# 25  2016                     184       Journal of neurotrauma
# 26  2017                     176       Journal of neurotrauma
# 27  2018                     243       Journal of neurotrauma
# 28  2019                     184       Journal of neurotrauma
# 29  2020                     199       Journal of neurotrauma
# 30  2021                      30       Journal of neurotrauma
